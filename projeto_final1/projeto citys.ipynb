# %%
#Projeto: programação para a ciencia de dados

# %%
import pandas as pd
import numpy as np

import datetime as dt 
import time

# %%
citys = pd.read_csv('projeto_final/Projeto-ciencia-de-dados/city_data.csv',sep='|',header=1, index_col="City")
citys
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 citys = pd.read_csv('projeto_final/Projeto-ciencia-de-dados/city_data.csv',sep='|',header=1, index_col="City")
#       2 citys
#
# ...

# %%
citys.head()
# Out:
#                    Population Density  Population  Working Age Population   \
# City
# Vienna, Austria                 310.0     2983513                2018818.0
# Salzburg, Austria               243.0      375489                 250472.0
# Brussels, Belgium               681.0     3284548                2137425.0
# Antwerp, Belgium                928.0     1139663                 723396.0
# Gent, Belgium                   552.0      645813                 417832.0
#
#                    Youth Dependency Ratio  Unemployment Rate  GDP per Capita  \
# City
# Vienna, Austria                      20.1               10.2         55770.0
# Salzburg, Austria                    20.3                3.0         66689.0
# Brussels, Belgium                    27.5               10.7         62500.0
# Antwerp, Belgium                     27.7                6.2         57595.0
# Gent, Belgium                        24.8                NaN         53311.0
#
# ...

# %%
#existem várias variaveis que demonstram algumas características de cada país/cidade como as médias.

# %%
citys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, Vienna, Austria to Adana, Turkiye
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Population Density               85 non-null     float64
#  1   Population                       86 non-null     int64
#  2   Working Age Population           85 non-null     float64
#  3   Youth Dependency Ratio           86 non-null     float64
#  4   Unemployment Rate                85 non-null     float64
#  5   GDP per Capita                   85 non-null     float64
#  6   Days of very strong heat stress  86 non-null     int64
#  7   Main Spoken Languages            85 non-null     object
#  8   Average Monthly Salary           86 non-null     int64
#  9   Avgerage Rent Price              86 non-null     int64
#  10  Average Cost of Living           86 non-null     int64
# ...

# %%
#podemos transformar algumas variaveis para que fiquem com menos peso, tipo float64 passar para float32
